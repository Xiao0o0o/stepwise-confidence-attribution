# %% [markdown]
# # Step-wise Confidence Estimation — End-to-End Demo (MoreHopQA, 10 cases)
#
# This notebook walks the **entire pipeline** on 10 MoreHopQA cases:
#
# 1. **Generate** reasoning traces  →  2. **Transform** into graphs  →
# 3. **BERT** embeddings  →  4. **Label** step correctness (LLM judge)  →
# 5. **Run methods** (NIBS, GIBS, P(True), white-box)  →  6. **Evaluate** (AUROC / AUPRC).
#
# Everything uses **relative paths**, so it runs straight after cloning the repo.
# All intermediate artifacts are written under `output/morehopqa/deepseek/`.
#
# > **GPU / API gating.** Some stages need a CUDA GPU (vLLM, DeBERTa, the baseline
# > LLMs) or an OpenAI key. Those cells detect what's available: if the requirement
# > is missing they print the exact command to run on a proper machine and continue.
# > CPU-only stages (transform, BERT-on-CPU, final metrics) always run for real, and
# > the **final evaluation falls back to bundled paper results** (`data/MorehopQA/Deepseek/`)
# > so you always see real numbers.

# %% [markdown]
# ## 0. Setup — work from the repo root and pick dataset/model

# %%
import os, sys, subprocess, json, pickle, shutil

os.environ["HF_HOME"] = "/home/ec2-user/SageMaker/hf_cache"
os.environ["HUGGINGFACE_HUB_CACHE"] = "/home/ec2-user/SageMaker/hf_cache/huggingface/hub"
os.environ["TRANSFORMERS_CACHE"] = "/home/ec2-user/SageMaker/hf_cache/transformers"
os.environ["OPENAI_API_KEY"] = "MY-API-KEY"


# Make sure we run from the repository root (this notebook lives in notebooks/)
if os.path.basename(os.getcwd()) == "notebooks":
    os.chdir("..")
REPO_ROOT = os.getcwd()
print("Repo root:", REPO_ROOT)

# Let us import the shared path/config module
sys.path.insert(0, os.path.join(REPO_ROOT, "src", "dataset"))
import dataset_config as dc

DATASET      = "morehopqa"
MODEL        = "phi4"                             # llama | deepseek | phi4
OUTPUT_ROOT  = "output"
SOURCE       = "data/source/morehopqa_sample.json"   # 10 cases
NUM_RESPONSES = 5                                   # samples per question (small for the demo)

# The baseline scripts (p_true / white_box) use a slightly different model key.
WB_MODEL = dc.WHITEBOX_MODEL_KEY[MODEL]              # deepseek -> "deepseek", llama -> "llama3"

# Canonical artifact paths (all derived in ONE place: dataset_config.py)
P = dict(
    responses   = dc.responses_path(OUTPUT_ROOT, DATASET, MODEL),
    transformed = dc.transformed_path(OUTPUT_ROOT, DATASET, MODEL),
    bert        = dc.bert_path(OUTPUT_ROOT, DATASET, MODEL),
    labels      = dc.evaluation_path(OUTPUT_ROOT, DATASET, MODEL),
    nibs        = dc.nibs_path(OUTPUT_ROOT, DATASET, MODEL),
    gibs        = dc.gibs_path(OUTPUT_ROOT, DATASET, MODEL),
    gib_ckpt    = dc.gib_checkpoint_dir(OUTPUT_ROOT, DATASET, MODEL),
    ptrue       = dc.ptrue_path(OUTPUT_ROOT, DATASET, MODEL),
    white_box   = dc.white_box_path(OUTPUT_ROOT, DATASET, MODEL),
)
for k, v in P.items():
    print(f"{k:11s} -> {v}")

# Bundled pre-computed paper results used as a no-GPU/no-key fallback in Stage 6.
BUNDLED = dict(
    labels    = "data/MorehopQA/Deepseek/evaluation.json",
    gibs      = "data/MorehopQA/Deepseek/GIBS_results.json",
    nibs      = "data/MorehopQA/Deepseek/NIBS_results.json",
    ptrue     = "data/MorehopQA/Deepseek/ptrue_deepseek_morehopqa.pkl",
    white_box = "data/MorehopQA/Deepseek/white_box_baseline_deepseek_r1.json",
)

HAS_GPU = False
try:
    import torch
    HAS_GPU = torch.cuda.is_available()
except Exception:
    pass
HAS_OPENAI_KEY = bool(os.environ.get("OPENAI_API_KEY"))
print("\nCUDA available:", HAS_GPU, "| OPENAI_API_KEY set:", HAS_OPENAI_KEY)

def run(cmd):
    """Run a shell command from the repo root and stream a trimmed output."""
    print("$", " ".join(cmd))
    res = subprocess.run(cmd, stdout=subprocess.PIPE, stderr=subprocess.STDOUT)
    out = res.stdout.decode("utf-8", "replace")
    print("\n".join(out.strip().splitlines()[-20:]))
    return res.returncode
# Out:
# Repo root: /home/ec2-user/stepwise-confidence-attribution
# responses   -> output/morehopqa/phi4/phi4_morehopqa_responses.pkl
# transformed -> output/morehopqa/phi4/transformed_phi4_morehopqa_with_probs.pkl
# bert        -> output/morehopqa/phi4/bert_embeddings_phi4_morehopqa_with_probs.pkl
# labels      -> output/morehopqa/phi4/evaluation.json
# nibs        -> output/morehopqa/phi4/NIBS_results.json
# gibs        -> output/morehopqa/phi4/GIBS_results.json
# gib_ckpt    -> output/morehopqa/phi4/gib_checkpoints
# ptrue       -> output/morehopqa/phi4/ptrue_phi4_morehopqa.pkl
# white_box   -> output/morehopqa/phi4/white_box_baseline_phi4.json
#
# CUDA available: True | OPENAI_API_KEY set: True

# %%
# Inspect the 10 demo cases
sample = json.load(open(SOURCE))
print(f"{len(sample)} cases. First one:")
print("  _id     :", sample[0]["_id"])
print("  question:", sample[0]["question"])
print("  answer  :", sample[0]["answer"])
# Out:
# 10 cases. First one:
#   _id     : 5ae789615542997ec2727695_12
#   question: How many letters are there between the first and last letters of the first name of the director of a 2004 film where Kam Heskin plays Paige Morgan in?
#   answer  : 4

# %% [markdown]
# ## 1. Generate reasoning traces  *(GPU + vLLM)*
#
# Real command:
#
# ```bash
# python src/dataset/generate_responds_vllm.py --dataset morehopqa --model deepseek \
#     --dataset-path data/source/morehopqa_sample.json --num-responses 5 --max-questions 10
# ```
#
# If no GPU is available we instead write a small **illustrative** responses file so
# the CPU stages below can run. It is clearly marked — replace it with real
# generation output for actual experiments.

# %%
os.makedirs(os.path.dirname(P["responses"]), exist_ok=True)

if HAS_GPU:
    run([sys.executable, "src/dataset/generate_responds_vllm.py",
         "--dataset", DATASET, "--model", MODEL,
         "--dataset-path", SOURCE,
         "--num-responses", str(NUM_RESPONSES), "--max-questions", "10"])
else:
    print("No GPU detected -> writing an ILLUSTRATIVE placeholder responses file.")
    print("(For real results, run the command above on a CUDA machine with vLLM.)\n")
    # Build a minimal but valid ReasoningGraph per case so the parser has something
    # to chew on. These are NOT real model samples — they are illustrative only.
    def fake_graph(q, ans, correct=True):
        a = ans if correct else "WRONG"
        return (f"ReasoningGraph(nodes=["
                f"ReasoningNode(id=1, description='Read the question', output='parsed', depends_on=[]), "
                f"ReasoningNode(id=2, description='Derive the answer', output='{a}', depends_on=[1])"
                f"], final_answer='{a}')")
    results = {}
    for d in sample:
        responses, rids, logps = [], [], []
        for i in range(NUM_RESPONSES):
            responses.append(fake_graph(d["question"], d["answer"], correct=(i % 2 == 0)))
            rids.append(i); logps.append(None)
        results[d["_id"]] = {
            "id": d["_id"], "question": d["question"], "context": d.get("context", ""),
            "answer": d["answer"], "response_ids": rids, "responses": responses,
            "token_ids": [[]] * NUM_RESPONSES, "logprobs": logps,
        }
    pickle.dump(results, open(P["responses"], "wb"))
    print("Wrote", P["responses"], "with", len(results), "questions x", NUM_RESPONSES, "responses")
# Out:
# $ /home/ec2-user/stepwise-confidence-attribution/.venv/bin/python src/dataset/generate_responds_vllm.py --dataset morehopqa --model phi4 --dataset-path data/source/morehopqa_sample.json --num-responses 5 --max-questions 10
# Processed prompts:  10%|█         | 1/10 [01:02<09:24, 62.72s/it, est. speed input: 7.37 toks/s, output: 21.09 toks/s]
#
# Processed prompts:  20%|██        | 2/10 [01:13<04:17, 32.17s/it, est. speed input: 12.57 toks/s, output: 39.03 toks/s]
#
# Processed prompts:  30%|███       | 3/10 [01:13<02:03, 17.61s/it, est. speed input: 18.78 toks/s, output: 59.91 toks/s]
#
# Processed prompts:  40%|████      | 4/10 [01:15<01:07, 11.31s/it, est. speed input: 24.50 toks/s, output: 79.64 toks/s]
#
# Processed prompts:  60%|██████    | 6/10 [01:15<00:21,  5.35s/it, est. speed input: 36.62 toks/s, output: 121.54 toks/s]
# Processed prompts: 100%|██████████| 10/10 [01:15<00:00,  7.56s/it, est. speed input: 60.86 toks/s, output: 205.74 toks/s]
#
# Processing batches: 100%|██████████| 4/4 [04:45<00:00, 71.59s/it]
# Processing batches: 100%|██████████| 4/4 [04:45<00:00, 71.35s/it]
#
# Saved checkpoint: 10 total questions processed
#
# Processing completed in 285.50 seconds
# Saved all results to output/morehopqa/phi4/phi4_morehopqa_responses.pkl
# Total responses generated: 43; questions: 10
# [rank0]:[W623 05:15:23.555847574 ProcessGroupNCCL.cpp:1250] Warning: WARNING: process group has NOT been destroyed before we destruct ProcessGroupNCCL. On normal program exit, the application should call destroy_process_group to ensure that any pending NCCL operations have finished in this process. In rare cases this process can exit before this point and block the progress of another member of the process group. This constraint has always been present,  but this warning has only been added since PyTorch 2.4 (function operator())

# %%
# Stage 1 Validation : Review Generated Responses

import pickle

path = "output/morehopqa/phi4/phi4_morehopqa_responses.pkl"
with open(path, "rb") as f:
    responses = pickle.load(f)

print(len(responses))
first_id = next(iter(responses))
print(first_id)
print(responses[first_id].keys())
print(responses[first_id]["responses"][0][:1000])
# Out:
# 10
# 5ae789615542997ec2727695_12
# dict_keys(['id', 'question', 'context', 'answer', 'response_ids', 'responses', 'token_ids', 'logprobs'])
# <think>We need to produce an object: ReasoningGraph with nodes and final answer. The output is based on input object: "How many letters are there between the first and last letters of the first name of the director of a 2004 film where Kam Heskin plays Paige Morgan in?" and context provided. We must produce a ReasoningGraph. Let's parse the question: "How many letters are there between the first and last letters of the first name of the director of a 2004 film where Kam Heskin plays Paige Morgan in?" The context: The film is "The Prince and Me", directed by Martha Coolidge, starring Julia Stiles, Luke Mably, Ben Miller, with Miranda Richardson, James Fox, and Alberta Watson. The film focuses on Paige Morgan, a pre-med college student in Wisconsin, pursued by a prince posing as a normal college student. In addition, the film is 2004. So director of 2004 film is Martha Coolidge. The question asks: "How many letters are there between the first and last letters of the first name of the dir

# %% [markdown]
# ## 2. Transform traces into structured graphs  *(CPU — runs for real)*

# %%
run([sys.executable, "src/dataset/tranformed_graph.py", "--dataset", DATASET, "--model", MODEL])

t = pickle.load(open(P["transformed"], "rb"))
pid = next(iter(t)); gid = next(iter(t[pid]))
print("\nExample transformed graph:")
print("  structure_retrieve:", t[pid][gid]["structure_retrieve"])
print("  string_q_a        :", t[pid][gid]["string_q_a"])
print("  response_str      :", t[pid][gid]["response_str"])
# Out:
# $ /home/ec2-user/stepwise-confidence-attribution/.venv/bin/python src/dataset/tranformed_graph.py --dataset morehopqa --model phi4
# No ReasoningNode objects found. Falling back to plain-text parser.
# No ReasoningNode objects found. Falling back to plain-text parser.
# No ReasoningNode objects found. Falling back to plain-text parser.
# No ReasoningNode objects found. Falling back to plain-text parser.
# No ReasoningNode objects found. Falling back to plain-text parser.
# No ReasoningNode objects found. Falling back to plain-text parser.
# No ReasoningNode objects found. Falling back to plain-text parser.
# No ReasoningNode objects found. Falling back to plain-text parser.
# Converting data format...
# Transformation complete. Data saved to output/morehopqa/phi4/transformed_phi4_morehopqa_with_probs.pkl
# Processed 10 problems with 43 total responses
#
# Example entry:
# ID: 5ae789615542997ec2727695_12_0
# Question: How many letters are there between the first and last letters of the first name of the director of a...
# Structure retrieve: Structure:{[NodeRaw, Node1, Edge1], [Node1, Node2, Edge2], [Node2, Node3, Edge3], [Node3, Node4, Edge4], [Node4, NodeResult, ResultEdge]}...
# Response: final_answer= 4.0
# Probs keys: ['Edge1', 'Edge2', 'Edge3', 'Edge4', 'ResultEdge']
#   Edge1: []
#   Edge2: []
#
# Example transformed graph:
#   structure_retrieve: Structure:{[NodeRaw, Node1, Edge1], [Node1, Node2, Edge2], [Node2, Node3, Edge3], [Node3, Node4, Edge4], [Node4, NodeResult, ResultEdge]}
#   string_q_a        : Edge1: Reasoning step 1?, Node1: We need to produce an object: ReasoningGraph with nodes and final answer.;
# Edge2: Reasoning step 2?, Node2: The output is based on input object: "How many letters are there between the first and last letters of the first name of the director of a 2004 film where Kam Heskin plays Paige Morgan in?" and context provided.;
# Edge3: Reasoning step 3?, Node3: We must produce a ReasoningGraph.;
# Edge4: Reasoning step 4?, Node4: Let's parse the question: "How many letters are there between the first and last letters of the first name of the director of a 2004 film where Kam Heskin plays Paige Morgan in?" The context: The film is "The Prince and Me", directed by Martha Coolidge, starring Julia Stiles, Luke Mably, Ben Miller, with Miranda Richardson, James Fox, and Alberta Watson.;
# ResultEdge: What is the final answer?, NodeResult: 4.0;
#   response_str      : final_answer= 4.0

# %%
trace = responses[first_id]["responses"][0]
print(trace)
# Out:
# <think>We need to produce an object: ReasoningGraph with nodes and final answer. The output is based on input object: "How many letters are there between the first and last letters of the first name of the director of a 2004 film where Kam Heskin plays Paige Morgan in?" and context provided. We must produce a ReasoningGraph. Let's parse the question: "How many letters are there between the first and last letters of the first name of the director of a 2004 film where Kam Heskin plays Paige Morgan in?" The context: The film is "The Prince and Me", directed by Martha Coolidge, starring Julia Stiles, Luke Mably, Ben Miller, with Miranda Richardson, James Fox, and Alberta Watson. The film focuses on Paige Morgan, a pre-med college student in Wisconsin, pursued by a prince posing as a normal college student. In addition, the film is 2004. So director of 2004 film is Martha Coolidge. The question asks: "How many letters are there between the first and last letters of the first name of the director?" The director's first name is "Martha". The question: "How many letters are there between the first and last letters of the first name of the director?" So we have: first letter of "Martha" is "M", last letter is "a". "Between" them: count letters in the string "Martha" that are strictly between the first and last letter. "Martha" is 6 letters: M a r t h a. So between first and last letter, the letters are: a, r, t, h. That's 4 letters. So answer: 4.
#
# I must produce output object: ReasoningGraph. The answer is 4.
#
# Now we need to produce ReasoningGraph object with nodes: Each node is a ReasoningNode. We need to produce a list of nodes that represent the reasoning steps. We are told: "Please structure your respond to the last INPUT_OBJECT based on the CONTEXT with OUTPUT_OBJECT according to OUTPUT_TYPE." There is a type ReasoningGraph. It must have a list of ReasoningNodes and final_answer field. We need to produce an object that instantiates ReasoningGraph with nodes and final_answer. We need to produce output object as valid Python code.
#
# The output must be valid Python code using the given type names.
#
# We need to produce: "class ReasoningGraph:" instance with nodes list and final_answer.
#
# We need to produce code: ReasoningGraph(nodes = [list of nodes], final_answer = 4). We need to produce a list of ReasoningNodes, each with id, description, output, and depends_on fields.
#
# We need to produce chain-of-thought nodes. We need to produce nodes for step: Identify film: "The Prince and Me" is the film. But the film is 2004 film where Kam Heskin plays Paige Morgan. But the film is "The Prince and Me" in 2004. Director: Martha Coolidge. Her first name: Martha. Then compute how many letters are between first and last letters: "Martha" first letter "M", last letter "a", count letters between: "a", "r", "t", "h", so count = 4.
#
# I need to produce nodes that capture reasoning steps. I can produce maybe three nodes:
# - Node 1: Identify film from context: "The Prince and Me" is the 2004 film where Kam Heskin plays Paige Morgan. But then how do we know it's directed by Martha Coolidge? We can produce node: "Identify director: Martha Coolidge".
# - Node 2: Extract director's first name: "Martha".
# - Node 3: Count letters between first and last letter of "Martha": between M and a are "a", "r", "t", "h", count = 4.
#
# Maybe produce three nodes in the chain-of-thought.
# But instructions say "ReasoningGraph" with nodes as ReasoningNode objects. The output object is ReasoningGraph. We need to produce a valid Python code snippet that instantiates ReasoningGraph. And each ReasoningNode should have id, description, output, depends_on.
#
# We produce nodes:
#
# We can produce:
# Node 0: "Identify the film and its director." But I need to produce steps in a chain-of-thought that leads to the final answer.
#
# Plan:
# - Node 1: "Extract film information: The film is 'The Prince and Me' from 2004." This node's output: "The Prince and Me"
# - Node 2: "Extract director information: Director is Martha Coolidge." output: "Martha Coolidge"
# - Node 3: "Extract first name of director: 'Martha'." output: "Martha"
# - Node 4: "Count letters between first and last letter in 'Martha'" output: 4
#
# But we need to produce chain-of-thought nodes. But instructions require valid Python code. Also we need to produce ReasoningGraph object with nodes and final_answer.
#
# We produce code snippet as Python code snippet. We have to produce object: ReasoningGraph(...)
#
# We produce code snippet:
# ```
# ReasoningGraph(
#     nodes=[
#        ReasoningNode(id=1, description="Identify the film: The Prince and Me (2004) is the film where Kam Heskin plays Paige Morgan.", output="The Prince and Me", depends_on=[]),
#        ReasoningNode(id=2, description="Identify the director of the film: Martha Coolidge.", output="Martha Coolidge", depends_on=[1]),
#        ReasoningNode(id=3, description="Extract the first name of the director: 'Martha'.", output="Martha", depends_on=[2]),
#        ReasoningNode(id=4, description="Count letters between the first and last letter of 'Martha'. First letter is 'M' and last letter is 'a'. The letters in between are 'a', 'r', 't', 'h'. Count is 4.", output=4, depends_on=[3])
#     ],
#     final_answer=4
# )
# ```
#
# We must produce this output. But the instructions require valid Python using the given type names. And we must produce code snippet in Python code snippet block.
#
# We must produce exactly the output: "OUTPUT_OBJECT:" that is a Python code snippet with ReasoningGraph(...) instantiation.
#
# The instructions: "Please structure your respond to the last INPUT_OBJECT based on the CONTEXT with OUTPUT_OBJECT according to OUTPUT_TYPE." So produce an answer that uses ReasoningGraph.
#
# I'll produce code snippet accordingly.
#
# I'll produce Python code snippet using the defined classes. We'll produce "ReasoningGraph" with "nodes" list containing ReasoningNode objects and final_answer field.
#
# I'll produce code snippet exactly as required.
#
# I'll produce code snippet with four nodes. And final answer 4.
#
# I'll produce code snippet exactly.
#
# I'll produce Python code snippet with code snippet block.
#
# I'll produce code snippet:
# ```
# ReasoningGraph(
#     nodes=[
#         ReasoningNode(
#             id=1,
#             description="Identify the film from context: The Prince and Me (2004) is the film where Kam Heskin plays Paige Morgan.",
#             output="The Prince and Me",
#             depends_on=[]
#         ),
#         ReasoningNode(
#             id=2,

# %% [markdown]
# ## 3. BERT embeddings per step  *(GPU or CPU)*
#
# Uses `bert-base-uncased`. We pass `--device cpu` automatically when there is no GPU
# (downloads the ~420 MB model the first time).

# %%
dev = "cuda" if HAS_GPU else "cpu"
run([sys.executable, "src/dataset/bert_graph.py",
     "--dataset", DATASET, "--model", MODEL, "--device", dev])

b = pickle.load(open(P["bert"], "rb"))
pid = next(iter(b)); gid = next(iter(b[pid]))
emb = b[pid][gid]["embeddings"]
print("\nEmbedding keys for one graph:", list(emb.keys()))
print("One embedding shape:", next(iter(emb.values())).shape)
# Out:
# $ /home/ec2-user/stepwise-confidence-attribution/.venv/bin/python src/dataset/bert_graph.py --dataset morehopqa --model phi4 --device cuda
# /home/ec2-user/stepwise-confidence-attribution/.venv/lib/python3.10/site-packages/transformers/utils/hub.py:105: FutureWarning: Using `TRANSFORMERS_CACHE` is deprecated and will be removed in v5 of Transformers. Use `HF_HOME` instead.
#   warnings.warn(
# Total question categories: 10
#
# Processing categories:   0%|          | 0/10 [00:00<?, ?it/s]
# Processing categories:  10%|█         | 1/10 [00:00<00:02,  3.12it/s]
# Processing categories:  20%|██        | 2/10 [00:00<00:01,  4.44it/s]
# Processing categories:  30%|███       | 3/10 [00:00<00:01,  3.78it/s]
# Processing categories:  40%|████      | 4/10 [00:01<00:01,  3.26it/s]
# Processing categories:  50%|█████     | 5/10 [00:01<00:01,  3.13it/s]
# Processing categories:  60%|██████    | 6/10 [00:01<00:01,  2.98it/s]
# Processing categories:  70%|███████   | 7/10 [00:02<00:01,  2.94it/s]
# Processing categories:  80%|████████  | 8/10 [00:02<00:00,  2.83it/s]
# Processing categories:  90%|█████████ | 9/10 [00:02<00:00,  2.95it/s]
# Processing categories: 100%|██████████| 10/10 [00:03<00:00,  3.06it/s]
# Processing categories: 100%|██████████| 10/10 [00:03<00:00,  3.11it/s]
#
# BERT embeddings with probability data saved to output/morehopqa/phi4/bert_embeddings_phi4_morehopqa_with_probs.pkl
#
# Embedding keys for one graph: ['Edge1', 'Node1', 'Edge2', 'Node2', 'Edge3', 'Node3', 'Edge4', 'Node4', 'ResultEdge', 'NodeResult', 'NodeRaw']
# One embedding shape: (768,)

# %% [markdown]
# ## 4. Label step correctness with an LLM judge  *(OpenAI key)*
#
# Real command:
#
# ```bash
# export OPENAI_API_KEY=sk-...
# python src/evaluation/gpt_eval.py --dataset morehopqa --model deepseek \
#     --source data/source/morehopqa_sample.json
# ```
#
# Without a key this runs a **dry run**: `evaluation.json` gets the correct schema
# but every label is `-1` (unknown). For meaningful metrics, set a real key here or
# reuse a pre-computed `evaluation.json`.

# %%
HAS_OPENAI_KEY = bool(os.environ.get("OPENAI_API_KEY"))

cmd = [sys.executable, "src/evaluation/gpt_eval.py",
       "--dataset", DATASET, "--model", MODEL, "--source", SOURCE]
if not HAS_OPENAI_KEY:
    print("No OPENAI_API_KEY -> dry run (labels will be -1).\n")
run(cmd)

labels = json.load(open(P["labels"]))
pid = next(iter(labels)); gid = next(iter(labels[pid]))
print("\nExample label record:")
print(json.dumps(labels[pid][gid]["evaluations"][:2], indent=2))
# Out:
# $ /home/ec2-user/stepwise-confidence-attribution/.venv/bin/python src/evaluation/gpt_eval.py --dataset morehopqa --model phi4 --source data/source/morehopqa_sample.json
# Labeling 10 problems from output/morehopqa/phi4/transformed_phi4_morehopqa_with_probs.pkl
# [1/10] 5ae789615542997ec2727695_12
# [2/10] 5ae6828f5542996d980e7bb9_12
# [3/10] 5ae457a95542996836b02c85_4
# [4/10] 5ab3eeb5554299233954fff4_1
# [5/10] 5ae835f25542997ec272776f_1
# [6/10] 5a81dacc55429926c1cdada0_8
# [7/10] 5ac23f9555429951e9e684db_8
# [8/10] 5ac23f9555429951e9e684db_15
# [9/10] 5ae738f75542991bbc9761c4_3
# [10/10] 5a7997a2554299029c4b5f59_3
#
# Saved correctness labels to output/morehopqa/phi4/evaluation.json
#
# Example label record:
# [
#   {
#     "index": 1,
#     "edge_name": "Edge1",
#     "edge_desc": "Reasoning step 1",
#     "node_name": "Node1",
#     "node_value": "We need to produce an object: ReasoningGraph with nodes and final answer.",
#     "is_correct": 1
#   },
#   {
#     "index": 2,
#     "edge_name": "Edge2",
#     "edge_desc": "Reasoning step 2",
#     "node_name": "Node2",
#     "node_value": "The output is based on input object: \"How many letters are there between the first and last letters of the first name of the director of a 2004 film where Kam Heskin plays Paige Morgan in?\" and context provided.",
#     "is_correct": 1
#   }
# ]

# %% [markdown]
# ## 5. Run the confidence-estimation methods  *(GPU)*
#
# NIBS (DeBERTa-MNLI), GIBS (train + infer) and the two baselines all need a GPU and
# load large models, so here we only **execute them when a GPU is present**;
# otherwise the exact commands are printed for you to run on a proper machine.

# %%
def gib_latest_ckpt():
    d = P["gib_ckpt"]
    if not os.path.isdir(d):
        return None
    cands = [f for f in os.listdir(d) if f.startswith("gib_model_") and f.endswith(".pth")]
    return os.path.join(d, sorted(cands)[-1]) if cands else None

nibs_cmd = [sys.executable, "src/NIBS/similarity_based_baseline.py",
            "--label-file", P["labels"], "--embedding-file", P["bert"],
            "--output-file", P["nibs"], "--device", "cuda"]

gib_train_cmd = [sys.executable, "src/GIBS/GIB_MCS_wo_mcs_feature.py",
                 "--embedding-file", P["bert"], "--label-file", P["labels"],
                 "--save-dir", P["gib_ckpt"], "--epochs", "200"]

ptrue_cmd = [sys.executable, "src/baseline/p_true.py",
             "--model", WB_MODEL, "--dataset", "morehopqa",
             "--data_path", P["transformed"], "--save_path", P["ptrue"]]

white_box_cmd = [sys.executable, "src/baseline/white_box_baseline.py",
                 "--label-file", P["labels"], "--embedding-file", P["bert"],
                 "--transformed-file", P["transformed"], "--output-file", P["white_box"],
                 "--model-name", WB_MODEL, "--context-file", SOURCE]

if HAS_GPU:
    run(nibs_cmd)
    run(gib_train_cmd)
    ckpt = gib_latest_ckpt()
    if ckpt:
        run([sys.executable, "src/GIBS/evaluation_GIB_wo_mcs.py",
             "--model-path", ckpt, "--embedding-file", P["bert"],
             "--label-file", P["labels"], "--output-file", P["gibs"]])
    run(ptrue_cmd)
    run(white_box_cmd)
else:
    print("No GPU -> run these on a CUDA machine:\n")
    for c in (nibs_cmd, gib_train_cmd, ptrue_cmd, white_box_cmd):
        print("  " + " ".join(c) + "\n")
    print("  # then GIBS inference with the produced checkpoint:")
    print("  python src/GIBS/evaluation_GIB_wo_mcs.py --model-path <ckpt> \\")
    print(f"      --embedding-file {P['bert']} --label-file {P['labels']} --output-file {P['gibs']}")
# Out:
# $ /home/ec2-user/stepwise-confidence-attribution/.venv/bin/python src/NIBS/similarity_based_baseline.py --label-file output/morehopqa/phi4/evaluation.json --embedding-file output/morehopqa/phi4/bert_embeddings_phi4_morehopqa_with_probs.pkl --output-file output/morehopqa/phi4/NIBS_results.json --device cuda
# Kept 10 labeled problems
#
# Processing problems:   0%|          | 0/10 [00:00<?, ?it/s]
# Processing problems:  30%|███       | 3/10 [00:07<00:18,  2.63s/it]
# Processing problems:  40%|████      | 4/10 [00:20<00:35,  5.86s/it]
# Processing problems:  50%|█████     | 5/10 [00:27<00:31,  6.35s/it]
# Processing problems:  60%|██████    | 6/10 [00:39<00:31,  7.84s/it]
# Processing problems:  80%|████████  | 8/10 [00:50<00:13,  6.76s/it]
# Processing problems: 100%|██████████| 10/10 [00:57<00:00,  5.55s/it]
# Processing problems: 100%|██████████| 10/10 [00:57<00:00,  5.77s/it]
# Error building graph 5ae6828f5542996d980e7bb9_12_1: 'Node4'
# Error building graph 5ae835f25542997ec272776f_1_0: 'Node3'
# Error building graph 5ae835f25542997ec272776f_1_0: 'Node3'
# Error building graph 5ae835f25542997ec272776f_1_0: 'Node3'
# Error building graph 5ae738f75542991bbc9761c4_3_1: 'Node0'
# Error building graph 5ae738f75542991bbc9761c4_3_2: 'Node3'
# Error building graph 5a7997a2554299029c4b5f59_3_0: 'Node3'
# Error building graph 5a7997a2554299029c4b5f59_3_0: 'Node3'
# Error building graph 5a7997a2554299029c4b5f59_3_0: 'Node3'
# Analysis complete. Results saved to output/morehopqa/phi4/NIBS_results.json
# $ /home/ec2-user/stepwise-confidence-attribution/.venv/bin/python src/GIBS/GIB_MCS_wo_mcs_feature.py --embedding-file output/morehopqa/phi4/bert_embeddings_phi4_morehopqa_with_probs.pkl --label-file output/morehopqa/phi4/evaluation.json --save-dir output/morehopqa/phi4/gib_checkpoints --epochs 200
# NodeResult is invalid (-1) for 5a81dacc55429926c1cdada0_8_3
# NodeResult is invalid (-1) for 5ab3eeb5554299233954fff4_1_0
# NodeResult is invalid (-1) for 5ae835f25542997ec272776f_1_4
# NodeResult is invalid (-1) for 5a81dacc55429926c1cdada0_8_3
# Restored best model state
#
# ================================================================================
# Training Completed!
# Total epochs: 200
# Best loss: 0.178272
# Final loss: 0.239337
# Converged: False
#
# Saving model and results...
# Model saved to: output/morehopqa/phi4/gib_checkpoints/gib_model_20260623_053045.pth
# Complete model saved to: output/morehopqa/phi4/gib_checkpoints/gib_complete_model_20260623_053045.pth
# Metrics saved to: output/morehopqa/phi4/gib_checkpoints/training_metrics_20260623_053045.json
# Training curves saved to: output/morehopqa/phi4/gib_checkpoints/training_curves_20260623_053045.png
# Figure(1500x1000)
# Model summary saved to: output/morehopqa/phi4/gib_checkpoints/model_summary_20260623_053045.txt
# $ /home/ec2-user/stepwise-confidence-attribution/.venv/bin/python src/GIBS/evaluation_GIB_wo_mcs.py --model-path output/morehopqa/phi4/gib_checkpoints/gib_model_20260623_053045.pth --embedding-file output/morehopqa/phi4/bert_embeddings_phi4_morehopqa_with_probs.pkl --label-file output/morehopqa/phi4/evaluation.json --output-file output/morehopqa/phi4/GIBS_results.json
# /home/ec2-user/stepwise-confidence-attribution/.venv/lib/python3.10/site-packages/transformers/utils/hub.py:105: FutureWarning: Using `TRANSFORMERS_CACHE` is deprecated and will be removed in v5 of Transformers. Use `HF_HOME` instead.
#   warnings.warn(
# /home/ec2-user/stepwise-confidence-attribution/src/GIBS/evaluation_GIB_wo_mcs.py:17: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   checkpoint = torch.load(model_path, map_location=device)
# Some weights of the model checkpoint at microsoft/deberta-large-mnli were not used when initializing DebertaForSequenceClassification: ['config']
# - This IS expected if you are initializing DebertaForSequenceClassification from the checkpoint of a model trained on another task or with another architecture (e.g. initializing a BertForSequenceClassification model from a BertForPreTraining model).
# - This IS NOT expected if you are initializing DebertaForSequenceClassification from the checkpoint of a model that you expect to be exactly identical (initializing a BertForSequenceClassification model from a BertForSequenceClassification model).
# Initialized NLI model: microsoft/deberta-large-mnli on cuda:0
# Model loaded from output/morehopqa/phi4/gib_checkpoints/gib_model_20260623_053045.pth
# Total problems: 10
#
# Inference:   0%|          | 0/10 [00:00<?, ?it/s]
# Inference:  80%|████████  | 8/10 [00:00<00:00, 78.21it/s]
# Inference: 100%|██████████| 10/10 [00:00<00:00, 86.90it/s]
# NodeResult is invalid (-1) for 5ab3eeb5554299233954fff4_1_0
# NodeResult is invalid (-1) for 5ae835f25542997ec272776f_1_4
# NodeResult is invalid (-1) for 5a81dacc55429926c1cdada0_8_3
# Results saved to output/morehopqa/phi4/GIBS_results.json
# $ /home/ec2-user/stepwise-confidence-attribution/.venv/bin/python src/baseline/p_true.py --model phi4 --dataset morehopqa --data_path output/morehopqa/phi4/transformed_phi4_morehopqa_with_probs.pkl --save_path output/morehopqa/phi4/ptrue_phi4_morehopqa.pkl
# Loading checkpoint shards:  33%|███▎      | 2/6 [00:01<00:02,  1.36it/s]
# Loading checkpoint shards:  50%|█████     | 3/6 [00:02<00:02,  1.40it/s]
# Loading checkpoint shards:  67%|██████▋   | 4/6 [00:04<00:03,  1.54s/it]
# Loading checkpoint shards:  83%|████████▎ | 5/6 [00:39<00:13, 13.57s/it]
# Loading checkpoint shards: 100%|██████████| 6/6 [01:16<00:00, 21.52s/it]
# Loading checkpoint shards: 100%|██████████| 6/6 [01:16<00:00, 12.81s/it]
#
# Problems:   0%|          | 0/10 [00:00<?, ?it/s]
# Problems:  10%|█         | 1/10 [00:00<00:05,  1.79it/s]
# Problems:  20%|██        | 2/10 [00:00<00:02,  2.74it/s]
# Problems:  30%|███       | 3/10 [00:01<00:02,  2.56it/s]
# Problems:  40%|████      | 4/10 [00:01<00:02,  2.16it/s]
# Problems:  50%|█████     | 5/10 [00:02<00:02,  2.08it/s]
# Problems:  60%|██████    | 6/10 [00:02<00:02,  1.87it/s]
# Problems:  70%|███████   | 7/10 [00:03<00:01,  1.86it/s]
# Problems:  80%|████████  | 8/10 [00:04<00:01,  1.77it/s]
# Problems:  90%|█████████ | 9/10 [00:04<00:00,  1.91it/s]
# Problems: 100%|██████████| 10/10 [00:04<00:00,  2.00it/s]
# Problems: 100%|██████████| 10/10 [00:04<00:00,  2.01it/s]
# Saved results to output/morehopqa/phi4/ptrue_phi4_morehopqa.pkl
# $ /home/ec2-user/stepwise-confidence-attribution/.venv/bin/python src/baseline/white_box_baseline.py --label-file output/morehopqa/phi4/evaluation.json --embedding-file output/morehopqa/phi4/bert_embeddings_phi4_morehopqa_with_probs.pkl --transformed-file output/morehopqa/phi4/transformed_phi4_morehopqa_with_probs.pkl --output-file output/morehopqa/phi4/white_box_baseline_phi4.json --model-name phi4 --context-file data/source/morehopqa_sample.json
# INFO:__main__:Initialized analyzer with 24 correct graphs
# INFO:__main__:Processing 10 labeled problems
#
# Processing problems:   0%|          | 0/10 [00:00<?, ?it/s]
# Processing problems:  20%|██        | 2/10 [00:01<00:05,  1.47it/s]
# Processing problems:  30%|███       | 3/10 [00:01<00:03,  1.86it/s]
# Processing problems:  40%|████      | 4/10 [00:02<00:04,  1.41it/s]
# Processing problems:  50%|█████     | 5/10 [00:03<00:03,  1.44it/s]
# Processing problems:  60%|██████    | 6/10 [00:03<00:02,  1.48it/s]
# Processing problems:  70%|███████   | 7/10 [00:05<00:02,  1.01it/s]
# Processing problems:  80%|████████  | 8/10 [00:06<00:01,  1.12it/s]
# Processing problems: 100%|██████████| 10/10 [00:06<00:00,  1.62it/s]
# Processing problems: 100%|██████████| 10/10 [00:06<00:00,  1.44it/s]
# INFO:__main__:Total graphs encountered: 43
# INFO:__main__:Correct graphs skipped: 24
# INFO:__main__:Incorrect graphs processed: 19
# INFO:__main__:Analysis complete. Results saved to output/morehopqa/phi4/white_box_baseline_phi4.json
# INFO:__main__:=== Final Results ===
# INFO:__main__:Total incorrect graphs analyzed: 19
# INFO:__main__:Output saved to: output/morehopqa/phi4/white_box_baseline_phi4.json

# %% [markdown]
# ## 6. Evaluate every method  *(CPU — runs for real)*
#
# We compute **AUROC / AUPRC / Accuracy@80%-coverage** for each method.
#
# - If your demo produced all five method outputs (i.e. you ran Stage 5 on a GPU and
#   had real labels), this scores the demo run.
# - Otherwise we fall back to the **bundled pre-computed paper results** in
#   `data/MorehopQA/Deepseek/` so you always see a real metrics table.

# %%
demo_ready = all(os.path.exists(P[k]) for k in ("labels", "gibs", "nibs", "ptrue", "white_box"))
# A dry-run labels file (all -1) can't produce metrics, so verify there are real labels.
real_labels = False
if os.path.exists(P["labels"]):
    lab = json.load(open(P["labels"]))
    for prob in lab.values():
        for gen in prob.values():
            if any(e["is_correct"] in (0, 1) for e in gen["evaluations"]):
                real_labels = True; break
        if real_labels: break

if demo_ready and real_labels:
    print(f"Scoring the DEMO run ({os.path.dirname(P['labels'])}/).\n")
    run([sys.executable, "src/evaluation/evaluation_metrics.py",
         "--dataset", DATASET, "--model", MODEL])
else:
    print("Demo method outputs / real labels not all present "
          "(expected without a GPU + OpenAI key).")
    print("Falling back to bundled paper results: data/MorehopQA/Deepseek/\n")
    run([sys.executable, "src/evaluation/evaluation_metrics.py",
         "--label-file",     BUNDLED["labels"],
         "--gib-file",       BUNDLED["gibs"],
         "--nibs-file",      BUNDLED["nibs"],
         "--ptrue-file",     BUNDLED["ptrue"],
         "--white-box-file", BUNDLED["white_box"]])
# Out:
# Scoring the DEMO run (output/morehopqa/phi4/).
#
# $ /home/ec2-user/stepwise-confidence-attribution/.venv/bin/python src/evaluation/evaluation_metrics.py --dataset morehopqa --model phi4
#   AUCPR = 0.4898
#   Accuracy@80% coverage = 0.3816
#
# leco Results:
#   Samples: 95, Positives: 33, Negatives: 62
#   AUROC = 0.3338
#   AUCPR = 0.2728
#   Accuracy@80% coverage = 0.3026
#
# Summary:
# Method          AUROC      AUCPR      Acc@80%
# GIB-based       0.4423     0.3174     0.3158
# Cos-Max         0.3478     0.3778     0.4468
# Cos-Mean        0.4450     0.4339     0.4468
# NLI-Max         0.3507     0.4060     0.4043
# NLI-Mean        0.4271     0.4689     0.4043
# Ptrue           0.6307     0.5321     0.3816
# sl_norm         0.4748     0.3146     0.3289
# entropy         0.6588     0.4898     0.3816
# leco            0.3338     0.2728     0.3026

# %% [markdown]
# ## Recap
#
# You just ran the full path: **generate → transform → bert → label → methods →
# evaluate**, all with relative paths writing to `output/`.
#
# To reproduce real results end-to-end, run this notebook (or the equivalent
# commands in the [README](../README.md)) on a CUDA machine with an
# `OPENAI_API_KEY` set, optionally pointing `SOURCE` at `data/source/morehopqa_full.json`
# and raising `NUM_RESPONSES`.

# %% [markdown]
# ---
#
# ## 7. Reproduce the paper results  *(CPU — no GPU / API key needed)*
#
# All datasets and per-model method outputs from the paper are bundled under
# `data/<dataset>/<model>/`. This section calls the **same**
# [`src/evaluation/evaluation_metrics.py`](../src/evaluation/evaluation_metrics.py)
# on each configuration and prints its **AUROC / AUPRC / Accuracy@80%-coverage**
# summary table.
#
# - Datasets: `MorehopQA`, `GSM8K`, `Math`  ×  Models: `Llama3.1`, `Phi4`, `Deepseek`.
# - Edit the `REPRODUCE` list below to output a specific *(dataset, model)* — e.g.
#   `[("MorehopQA", "Deepseek")]` — or keep `[("all", "all")]` for the full grid.
# - `GIB-based` is our method (**GIBS**); the other rows are baselines. Higher
#   AUROC / AUPRC is better.
#
# (The bundled files have slightly different names across folders, e.g.
# `NIBS_results.json` vs `similarity_results.json`; the helper below resolves them
# automatically.)

# %%
import os, sys, glob, subprocess

# Make this cell self-contained: locate the repo root (the dir that has both
# data/ and src/) so it works even if the Setup cell above wasn't run first.
_d = os.getcwd()
for _ in range(5):
    if os.path.isdir(os.path.join(_d, "data")) and os.path.isdir(os.path.join(_d, "src")):
        break
    _d = os.path.dirname(_d)
os.chdir(_d)
print("Repo root:", os.getcwd())

DATA_ROOT = "data"
# Folder names exactly as they appear under data/<dataset>/<model>/
PAPER_DATASETS = ["MorehopQA", "GSM8K", "Math"]
PAPER_MODELS   = ["Llama3.1", "Phi4", "Deepseek"]

# ---- Choose what to output. ("all", "all") runs every dataset x model. ----
# Examples:
#   REPRODUCE = [("MorehopQA", "Deepseek")]              # one config
#   REPRODUCE = [("GSM8K", "all"), ("Math", "Phi4")]     # mix
REPRODUCE = [("all", "all")]

def _find(d, *names):
    """Return the first existing file in d matching one of the given names/globs."""
    for n in names:
        p = os.path.join(d, n)
        if os.path.exists(p):
            return p
        hits = sorted(glob.glob(os.path.join(d, n)))
        if hits:
            return hits[0]
    return None

def discover_paper_files(d):
    # File names differ slightly across folders, so we try a few aliases each.
    return dict(
        label = _find(d, "evaluation.json", "evaluation_results.json"),
        gib   = _find(d, "GIBS_results.json", "GIB_results.json"),
        nibs  = _find(d, "NIBS_results.json", "similarity_results.json", "NIBS_results"),
        ptrue = _find(d, "ptrue_*.pkl"),
        white = _find(d, "white_box_baseline_*.json"),
    )

def reproduce(dataset, model):
    d = os.path.join(DATA_ROOT, dataset, model)
    if not os.path.isdir(d):
        print(f"  (no folder {d}) — skip"); return
    f = discover_paper_files(d)
    missing = [k for k, v in f.items() if v is None]
    if missing:
        print(f"  SKIP {dataset}/{model} — missing files: {missing}"); return
    res = subprocess.run(
        [sys.executable, "src/evaluation/evaluation_metrics.py",
         "--label-file", f["label"], "--gib-file", f["gib"], "--nibs-file", f["nibs"],
         "--ptrue-file", f["ptrue"], "--white-box-file", f["white"]],
        stdout=subprocess.PIPE, stderr=subprocess.STDOUT)
    out = res.stdout.decode("utf-8", "replace")
    # Show only the final summary table (AUROC / AUPRC / Acc@80% per method).
    print(out[out.index("Summary:"):].rstrip() if "Summary:" in out else out.strip()[-800:])

# Expand ("all", ...) selections, then run.
todo = []
for ds, m in REPRODUCE:
    dss = PAPER_DATASETS if ds == "all" else [ds]
    mss = PAPER_MODELS  if m  == "all" else [m]
    for a in dss:
        for b in mss:
            todo.append((a, b))

for ds, m in todo:
    print("=" * 72)
    print(f"### {ds}  /  {m}")
    print("=" * 72)
    reproduce(ds, m)
    print()
# Out:
# Repo root: /home/ec2-user/stepwise-confidence-attribution
# ========================================================================
# ### MorehopQA  /  Llama3.1
# ========================================================================
# Summary:
# Method          AUROC      AUCPR      Acc@80%
# GIB-based       0.6471     0.6694     0.5602
# Cos-Max         0.3836     0.4446     0.5179
# Cos-Mean        0.5044     0.5487     0.5275
# NLI-Max         0.4937     0.5485     0.5347
# NLI-Mean        0.5124     0.5535     0.5314
# Ptrue           0.5228     0.5486     0.5451
# sl_norm         0.4005     0.4506     0.5187
# entropy         0.5510     0.5413     0.5586
# leco            0.3280     0.4365     0.4921
#
# ========================================================================
# ### MorehopQA  /  Phi4
# ========================================================================
# Summary:
# Method          AUROC      AUCPR      Acc@80%
# GIB-based       0.6619     0.6866     0.7053
# Cos-Max         0.3454     0.5284     0.6413
# Cos-Mean        0.4779     0.6492     0.6388
# NLI-Max         0.5801     0.6637     0.6961
# NLI-Mean        0.5440     0.6428     0.6776
# Ptrue           0.5086     0.6159     0.6362
# sl_norm         0.3198     0.4966     0.5891
# entropy         0.6011     0.6702     0.6445
# leco            0.2760     0.4944     0.5782
#
# ========================================================================
# ### MorehopQA  /  Deepseek
# ========================================================================
# Summary:
# Method          AUROC      AUCPR      Acc@80%
# GIB-based       0.8084     0.8357     0.7051
# Cos-Max         0.3390     0.5129     0.6031
# Cos-Mean        0.5938     0.6919     0.6419
# NLI-Max         0.6663     0.7766     0.6457
# NLI-Mean        0.6291     0.6899     0.6498
# Ptrue           0.5177     0.6492     0.6607
# sl_norm         0.2463     0.4894     0.6049
# entropy         0.6103     0.7150     0.6812
# leco            0.3116     0.5777     0.5643
#
# ========================================================================
# ### GSM8K  /  Llama3.1
# ========================================================================
# Summary:
# Method          AUROC      AUCPR      Acc@80%
# GIB-based       0.6910     0.7004     0.6292
# Cos-Max         0.4537     0.5152     0.5513
# Cos-Mean        0.6078     0.6211     0.6175
# NLI-Max         0.7096     0.7890     0.5908
# NLI-Mean        0.5524     0.6103     0.5665
# Ptrue           0.4016     0.4711     0.5283
# sl_norm         0.4790     0.5240     0.5513
# entropy         0.4105     0.4962     0.5141
# leco            0.3862     0.4586     0.5319
#
# ========================================================================
# ### GSM8K  /  Phi4
# ========================================================================
# Summary:
# Method          AUROC      AUCPR      Acc@80%
# GIB-based       0.7892     0.8172     0.8117
# Cos-Max         0.3494     0.5861     0.7010
# Cos-Mean        0.5959     0.7703     0.7199
# NLI-Max         0.6600     0.8141     0.7446
# NLI-Mean        0.5738     0.7704     0.7186
# Ptrue           0.5251     0.6956     0.6936
# sl_norm         0.3851     0.5947     0.6799
# entropy         0.4623     0.6795     0.6664
# leco            0.2885     0.5735     0.6344
#
# ========================================================================
# ### GSM8K  /  Deepseek
# ========================================================================
# Summary:
# Method          AUROC      AUCPR      Acc@80%
# GIB-based       0.7289     0.6712     0.6532
# Cos-Max         0.5269     0.5197     0.5676
# Cos-Mean        0.6633     0.6933     0.5748
# NLI-Max         0.7450     0.6982     0.6409
# NLI-Mean        0.6762     0.6508     0.6318
# Ptrue           0.5159     0.5820     0.5840
# sl_norm         0.3700     0.5308     0.5015
# entropy         0.5203     0.5550     0.5235
# leco            0.3202     0.4110     0.4883
#
# ========================================================================
# ### Math  /  Llama3.1
# ========================================================================
# Summary:
# Method          AUROC      AUCPR      Acc@80%
# GIB-based       0.5855     0.4890     0.4513
# Cos-Max         0.4313     0.4021     0.4513
# Cos-Mean        0.5118     0.4848     0.4607
# NLI-Max         0.5173     0.5061     0.4743
# NLI-Mean        0.5148     0.4881     0.4670
# Ptrue           0.4584     0.4166     0.4551
# sl_norm         0.5138     0.4627     0.4626
# entropy         0.5120     0.4617     0.4550
# leco            0.4378     0.4252     0.4382
#
# ========================================================================
# ### Math  /  Phi4
# ========================================================================
# Summary:
# Method          AUROC      AUCPR      Acc@80%
# GIB-based       0.6946     0.8078     0.8322
# Cos-Max         0.3845     0.6617     0.7656
# Cos-Mean        0.6116     0.8503     0.7708
# NLI-Max         0.6043     0.8052     0.7925
# NLI-Mean        0.5739     0.8020     0.7712
# Ptrue           0.5277     0.7435     0.7554
# sl_norm         0.3841     0.6597     0.7340
# entropy         0.5190     0.7351     0.7479
# leco            0.4089     0.7279     0.7044
#
# ========================================================================
# ### Math  /  Deepseek
# ========================================================================
# Summary:
# Method          AUROC      AUCPR      Acc@80%
# GIB-based       0.5806     0.6831     0.6359
# Cos-Max         0.3376     0.5015     0.5937
# Cos-Mean        0.5363     0.6583     0.6177
# NLI-Max         0.5310     0.6676     0.6340
# NLI-Mean        0.5407     0.6694     0.6267
# Ptrue           0.5055     0.6298     0.6229
# sl_norm         0.4093     0.5433     0.6089
# entropy         0.5190     0.6259     0.6225
# leco            0.3838     0.5836     0.5901
